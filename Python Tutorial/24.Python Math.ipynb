# %% [markdown]
# # ➗ Python `math` Module
#
# The `math` module provides **mathematical functions** like square roots, trigonometry, logarithms, constants, etc.
#
# ---
#
# ### 🔹 Import the Module
#
# ```python
# import math
# ```
#
# ---
#
# ### 1️⃣ Common Math Functions
#
# ```python
# print(math.sqrt(16))     # ✅ Square root → 4.0
# print(math.pow(2, 3))    # ✅ Power → 8.0
# print(math.factorial(5))# ✅ Factorial → 120
# print(math.fabs(-10))   # ✅ Absolute value → 10.0
# ```
#
# ---
#
# ### 2️⃣ Rounding Functions
#
# ```python
# print(math.floor(3.9))   # ⬇️ Floor → 3
# print(math.ceil(3.2))    # ⬆️ Ceil → 4
# print(math.trunc(5.99))  # ✂️ Truncate → 5
# ```
#
# ---
#
# ### 3️⃣ Trigonometric Functions
#
# ```python
# print(math.sin(math.pi/2))  # sin(90°) → 1.0
# print(math.cos(0))          # cos(0°) → 1.0
# print(math.tan(math.pi/4))  # tan(45°) → ~1.0
# ```
#
# ---
#
# ### 4️⃣ Logarithmic & Exponential Functions
#
# ```python
# print(math.log(100, 10))   # log base 10 → 2.0
# print(math.log2(8))        # log base 2 → 3.0
# print(math.exp(2))         # e^2 → ~7.39
# ```
#
# ---
#
# ### 5️⃣ Constants
#
# ```python
# print(math.pi)      # π = 3.141592653...
# print(math.e)       # e = 2.718281828...
# print(math.tau)     # τ = 6.283185307...
# ```
#
# ---
#
# ### 🧾 Summary Table
#
# | Function            | Description                         |
# | ------------------- | ----------------------------------- |
# | `math.sqrt(x)`      | Square root of `x`                  |
# | `math.pow(x, y)`    | `x` to the power `y`                |
# | `math.factorial(x)` | Factorial of `x`                    |
# | `math.floor(x)`     | Round down                          |
# | `math.ceil(x)`      | Round up                            |
# | `math.trunc(x)`     | Truncate to integer                 |
# | `math.log(x, base)` | Logarithm base `base` (default `e`) |
# | `math.sin(x)`       | Sine of `x` radians                 |
# | `math.pi`, `math.e` | Math constants                      |
#
# ---
#
# ### 💡 Tip:
#
# * All angles in `math` trigonometric functions are in **radians**
#
#   * To convert degrees to radians:
#
#     ```python
#     math.radians(90)  # → π/2
#     ```
